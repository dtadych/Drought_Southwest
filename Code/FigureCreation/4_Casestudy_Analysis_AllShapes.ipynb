# %% [markdown]
# # Case Study Analysis Notebook
#
# The purpose of this code is to create a set of graphs based on one shapefile of many polygons.  In this way it is a little more complicated than our Casestudy_Analysis.ipynb but the principles are the same.  This produces graphs from our paper for our case study analysis.
#
# To run this code, you need the following files in the appropriate folders
#  - Data/Input_files
#    > Master_ADWR_database_noduplicates.shp
#    > Master_ADWR_database_water.shp
#    > Yearly_DroughtIndices_updated12032023.csv
#  - Data/Output_files
#    > Wells55_GWSI_WLTS_DB_annual_updated_thresh15outliersdeleted.csv
#  - Data/Shapefiles
#    > Any shapefiles of your choosing

# %%
# Packages and paths
# %%
from optparse import Values
import os
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.colors import ListedColormap
import datetime
from matplotlib.transforms import Bbox
import numpy as np
import pandas as pd
from shapely.geometry import box
import geopandas as gp
#import earthpy as et
import scipy.stats as sp
from scipy.stats import kendalltau, pearsonr, spearmanr
import pymannkendall as mk
import sys

# Add the path to the Utils folder
utils_path = os.path.abspath(os.path.join('..', 'Utils'))
if utils_path not in sys.path:
    sys.path.append(utils_path)

# Now you can import the functions from CustomFunctions.py
import CustomFunctions as cf

# Local paths
datapath = '../../Data'
inputpath = '../../Data/Input'
outputpath = '../../Data/Output/Local'
shapepath = inputpath+'/Shapefiles'
figurepath = '../../Figures/'

# %%
# %% Creating colors
c_1 = '#8d5a99' # Reservation
c_2 = "#d7191c" # Regulated with CAP (Water Category Color)
c_3 = '#e77a47' # Regulated without CAP (Water Category Color)
c_4 = '#2cbe21' # Lower CO River - SW (Water Category Color)
c_5 = '#2f8c73' # Upper CO River - Mixed (Water Category Color)
c_6 = '#6db7e8' # SE - GW
c_7 = '#165782' # NW - GW (Water Category color)
c_8 = '#229ce8' # SC - GW
c_9 = '#1f78b4' # NE - GW
c_10 = '#41bf9e' # N - Mixed
c_11 = '#7adec4' # C - Mixed
drought_color = '#ffa6b8'
wet_color = '#b8d3f2'

reg_colors = [c_2,c_7]
georeg_colors = [c_1,c_2,c_3,c_4,c_5,c_6,c_7,c_8,c_9,c_10,c_11]
SW_colors = [c_2,c_3,c_4,c_5,c_7]

bar_watercatc = [c_2,c_3,c_4,c_5,c_7]


# Color blind palette
# https://jacksonlab.agronomy.wisc.edu/2016/05/23/15-level-colorblind-friendly-palette/
blind =["#000000","#004949","#009292","#ff6db6","#ffb6db",
 "#490092","#006ddb","#b66dff","#6db6ff","#b6dbff",
 "#920000","#924900","#db6d00","#24ff24","#ffff6d"]

# Matching new map

grace_color = '#A92B2A'
az_wells_color = '#1D4E77'

cap = '#77A8A5' #'#C6652B'
cap_secondary = '#004D40'
# noCAP = '#EDE461' # This is one from the map
noCAP = '#CCC339' # This color but darker for lines
GWdom = '#3B76AF'
mixed = '#6EB2E4'
swdom = '#469B76'

# %%
# %% Drought dictionary
DROUGHT_YEARS = {
        # 1:[1989,1990]
        # ,2:[1996]
        3:[2002,2003]
        ,4:[2006,2007]
        ,5:[2012,2013,2014]
        ,6:[2018]
        ,7:[2021]}

print(DROUGHT_YEARS)
# Out:
# {3: [2002, 2003], 4: [2006, 2007], 5: [2012, 2013, 2014], 6: [2018], 7: [2021]}

# %%
#%% Pre-drought
# PREDROUGHT_YEARS = {1:[1988]
#         ,2:[1995]
#         ,3:[2001]
#         ,4:[2005]
#         ,5:[2011]
#         ,6:[2017]}

PREDROUGHT_YEARS = {1:[*range(1975,1988,1)]
        ,2:[*range(1991,1995,1)]
        ,3:[*range(1997,2001,1)]
        ,4:[*range(2004,2005,1)]
        ,5:[*range(2006,2011,1)]
        ,6:[*range(2015,2017,1)]}

print(PREDROUGHT_YEARS)
# Out:
# {1: [1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987], 2: [1991, 1992, 1993, 1994], 3: [1997, 1998, 1999, 2000], 4: [2004], 5: [2006, 2007, 2008, 2009, 2010], 6: [2015, 2016]}

# %% [markdown]
# Read in the main databases.  You only have to do this once.
#
# Master Database might take a while (~5-7 minutes).

# %%
# Read in the main Static Database

filename_mdb_nd = 'Master_ADWR_database_noduplicates.shp'
filepath = os.path.join(inputpath_local, filename_mdb_nd)
print(filepath)

masterdb = gp.read_file(filepath)
pd.options.display.float_format = '{:.2f}'.format
print(masterdb.info())
# Out:
# ../Data/Input_files\Master_ADWR_database_noduplicates.shp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 filepath = os.path.join(inputpath_local, filename_mdb_nd)
#       5 print(filepath)
# ----> 7 masterdb = gp.read_file(filepath)
#       8 pd.options.display.float_format = '{:.2f}'.format
#       9 print(masterdb.info())
#
# File c:\Users\det19\.conda\envs\azgwspatialanalysis\lib\site-packages\geopandas\io\file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     278     else:
#     279         path_or_bytes = filename
# --> 281     return _read_file_fiona(
#     282         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     283     )
#     285 else:
#     286     raise ValueError(f"unknown engine '{engine}'")
#
# File c:\Users\det19\.conda\envs\azgwspatialanalysis\lib\site-packages\geopandas\io\file.py:379, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     375     df = pd.DataFrame(
#     376         [record["properties"] for record in f_filt], columns=columns
#     377     )
#     378 else:
# --> 379     df = GeoDataFrame.from_features(
#     380         f_filt, crs=crs, columns=columns + ["geometry"]
#     381     )
#     382 for k in datetime_fields:
#     383     as_dt = pd.to_datetime(df[k], errors="ignore")
#
# File c:\Users\det19\.conda\envs\azgwspatialanalysis\lib\site-packages\geopandas\geodataframe.py:640, in GeoDataFrame.from_features(cls, features, crs, columns)
#     637 if hasattr(feature, "__geo_interface__"):
#     638     feature = feature.__geo_interface__
#     639 row = {
# --> 640     "geometry": shape(feature["geometry"]) if feature["geometry"] else None
#     641 }
#     642 # load properties
#     643 properties = feature["properties"]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shapely\geometry\geo.py:95, in shape(context)
#      93     return _empty_shape_for_no_coordinates(geom_type)
#      94 elif geom_type == "point":
# ---> 95     return Point(ob["coordinates"])
#      96 elif geom_type == "linestring":
#      97     return LineString(ob["coordinates"])
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shapely\geometry\point.py:78, in Point.__new__(self, *args)
#      76 if not np.issubdtype(coords.dtype, np.number):
#      77     coords = [float(c) for c in coords]
# ---> 78 geom = shapely.points(coords)
#      79 if not isinstance(geom, Point):
#      80     raise ValueError("Invalid values passed to Point constructor")
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shapely\creation.py:74, in points(coords, y, z, indices, out, **kwargs)
#      72 coords = _xyz_to_coords(coords, y, z)
#      73 if indices is None:
# ---> 74     return lib.points(coords, out=out, **kwargs)
#      75 else:
#      76     return simple_geometries_1d(coords, indices, GeometryType.POINT, out=out)
#
# KeyboardInterrupt:

# %% [markdown]
# This one takes about 3-4 minutes to run

# %%
# Read in the database of number water wells
filename_mdb_w = 'Master_ADWR_database_water.shp'
filepath = os.path.join(inputpath_local, filename_mdb_w)
print(filepath)

masterdb_water = gp.read_file(filepath)
pd.options.display.float_format = '{:.2f}'.format
print(masterdb_water.info())
# Out:
# ../Data/Input_files\Master_ADWR_database_water.shp
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 140185 entries, 0 to 140184
# Data columns (total 72 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Combo_ID    140185 non-null  object
#  1   SITE_ID     45565 non-null   object
#  2   LOCAL_ID    45565 non-null   object
#  3   REGISTRY_I  119032 non-null  object
#  4   WELL_TYPE   45565 non-null   object
#  5   DD_LAT      45565 non-null   float64
#  6   DD_LONG     45565 non-null   float64
#  7   WELL_ALT    45565 non-null   float64
#  8   WATER_USE_  45507 non-null   object
#  9   WELL_DEPTH  139606 non-null  float64
#  10  CASE_DIAM   45565 non-null   float64
#  11  LASTWLDATE  34356 non-null   object
#  12  WL_DTW      45565 non-null   float64
#  13  WL_ELEV     45565 non-null   float64
#  14  QUASI_IDX_  11 non-null      object
#  15  GOES_ENABL  171 non-null     object
#  16  TRANSDUCER  171 non-null     object
#  17  IDXBK2      49 non-null      object
#  18  FREQUENCY   2262 non-null    object
#  19  Original_D  140185 non-null  object
#  20  OBJECTID    100676 non-null  float64
#  21  PROGRAM     100676 non-null  object
#  22  OWNER_NAME  100488 non-null  object
#  23  RGR_PUMP_D  100676 non-null  object
#  24  WELLTYPE    100676 non-null  object
#  25  WELL_TYPE_  100676 non-null  object
#  26  DLIC_NUM    100382 non-null  object
#  27  APPROVED    64490 non-null   object
#  28  INSTALLED   84604 non-null   object
#  29  WATER_LEVE  94501 non-null   float64
#  30  CASING_DEP  99389 non-null   float64
#  31  CASING_DIA  99199 non-null   float64
#  32  CASING_TYP  99632 non-null   object
#  33  PUMP_TYPE   53778 non-null   object
#  34  PUMP_POWER  53586 non-null   object
#  35  PUMPRATE    52949 non-null   float64
#  36  TESTEDRATE  52854 non-null   float64
#  37  DRAW_DOWN   50690 non-null   float64
#  38  COMPLETION  50990 non-null   object
#  39  DRILL_LOG   100676 non-null  object
#  40  WELL_CANCE  1359 non-null    object
#  41  CADASTRAL   100676 non-null  object
#  42  COUNTY      100676 non-null  object
#  43  WATERSHED   100676 non-null  object
#  44  BASIN_NAME  100676 non-null  object
#  45  SUBBASIN_N  100676 non-null  object
#  46  AMA         100676 non-null  object
#  47  QUAD_CODE   100676 non-null  object
#  48  WHOLE_TOWN  100676 non-null  object
#  49  HALF_TOWNS  100671 non-null  object
#  50  NORTHSOUTH  100676 non-null  object
#  51  WHOLE_RANG  100676 non-null  object
#  52  HALF_RANGE  100671 non-null  object
#  53  EASTWEST    100676 non-null  object
#  54  SECTION     100676 non-null  object
#  55  QUARTER_16  100672 non-null  object
#  56  QACRE160DI  100270 non-null  object
#  57  QUARTER_40  100669 non-null  object
#  58  QACRE40DIR  100177 non-null  object
#  59  QUARTER_10  100651 non-null  object
#  60  QACRE10DIR  99813 non-null   object
#  61  UTM_X_METE  100676 non-null  float64
#  62  UTM_Y_METE  100676 non-null  float64
#  63  APPLICATIO  100619 non-null  object
#  64  ADDRESS1    100488 non-null  object
#  65  ADDRESS2    6747 non-null    object
#  66  CITY        100488 non-null  object
#  67  STATE       100438 non-null  object
#  68  ZIP         100438 non-null  object
#  69  ZIP4        4709 non-null    object
#  70  WATER_US_1  100257 non-null  object
#  71  geometry    140185 non-null  geometry
# dtypes: float64(16), geometry(1), object(55)
# memory usage: 77.0+ MB
# None

# %%
# Read in the annual time series database
# This file was created in Well_Timeseries_merge.py

filename_ts = 'Wells55_GWSI_WLTS_DB_annual_updated_thresh15outliersdeleted.csv'
filepath = os.path.join(outputpath_local, filename_ts)
print(filepath)
annual_db = pd.read_csv(filepath, header=1, index_col=0)

#Block to do some formatting
annual_db = annual_db[1:168102]
annual_db.index = annual_db.index.astype('int64')
annual_db2 = annual_db.reset_index(inplace=True)
annual_db2 = annual_db.rename(columns = {'year':'Combo_ID'})
annual_db2.head()
# Out:
# ../Data/Output_files/Wells55_GWSI_WLTS_DB_annual_updated_thresh15outliersdeleted.csv
#    Combo_ID  1853.0  1856.0  1857.0  1860.0  1864.0  1868.0  1870.0  1871.0  \
# 0     60001     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     85358     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     85761     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     85799     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     85863     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    1872.0  ...  2014.0  2015.0  2016.0  2017.0  2018.0  2019.0  2020.0  \
# 0     NaN  ...  503.90  497.70  495.30     NaN  489.85     NaN  487.85
# 1     NaN  ...  264.73     NaN  262.43  254.88  251.65  251.53     NaN
# 2     NaN  ...   44.90   44.70   45.50   45.30   46.30   45.00   46.20
# 3     NaN  ...   58.90   59.30   59.80   57.80   59.50   60.10   59.40
# 4     NaN  ...  112.64  114.74  115.50  116.26  117.10  119.34  118.49
#
#    2021.0  2022.0  2023.0
# 0  485.10  483.50     NaN
# 1     NaN     NaN     NaN
# 2   43.50     NaN     NaN
# 3   60.80   62.10     NaN
# 4  119.77  120.65  118.66
#
# [5 rows x 160 columns]

# %% [markdown]
# ### From here down is where you can rerun the code to generate graphs

# %%
# Read in the shapefile

# filename_shapeile = 'georeg_reproject_fixed.shp'
filename_shapeile = 'AllCaseStudies.shp'
filepath = os.path.join(shapepath_local, filename_shapeile)
shapefile = gp.read_file(filepath)
shapefile.plot(cmap='viridis')
# Out:
# <Axes: >

# %%
shapefile
# Out:
#              Name   FID AMA_CODE            SUBBASIN_N NAME_ABBR  \
# 0         GSF/USF   NaN      NaN                   NaN       NaN
# 1             USF   NaN      NaN                   NaN       NaN
# 2         Control   NaN      NaN                   NaN       NaN
# 3       Flagstaff 14.00      NaN                   NaN       NaN
# 4       LittleCoR   NaN        A  JOSEPHCITY_LITTLECOR       JCI
# 5         Douglas   NaN        0               DOUGLAS       DOU
# 6         Phoenix 78.00      NaN                   NaN       NaN
# 7        GilaBend   NaN        0             GILA BEND       GIL
# 8      Harquahala   NaN        G            HARQUAHALA       HAR
# 9        McMullen   NaN        0       MCMULLEN VALLEY       MMU
# 10  RanegrasPlain   NaN        0        RANEGRAS PLAIN       RAN
# 11      SaltRiver   NaN        0      SALT RIVER LAKES       SRL
# 12         Tucson 69.00      NaN                   NaN       NaN
# 13          Verde   NaN        0          VERDE VALLEY       VER
# 14         Wilcox   NaN        0               WILLCOX       WIL
# 15           Yuma   NaN        0                  YUMA       YUM
#
#                  SUBBASIN_1      SHAPEAREA               layer  \
# 0                       NaN            NaN    AvraValleyGSFUSF
# 1                       NaN            NaN    AvraValleyGSFUSF
# 2                       NaN            NaN    AvraValleyGSFUSF
# 3                       NaN            NaN  Flagstaff_Buffered
# 4   JOSEPHCITYINA_LITTLECoR 69171676398.62   Little Co.  River
# 5                   DOUGLAS  2458077525.61  DouglasAMA_updated
# 6                       NaN            NaN     Phoenix (Urban)
# 7                 GILA BEND  3325765955.50            GilaBend
# 8            HARQUAHALA INA  1983266748.69          Harquahala
# 9           MCMULLEN VALLEY  1680258416.27      McMullenValley
# 10           RANEGRAS PLAIN  2361281724.94       RanegrasPlain
# 11         SALT RIVER LAKES  3143787411.27           SaltRiver
# 12                      NaN            NaN              Tucson
# 13             VERDE VALLEY  6477965113.57               Verde
# 14                  WILLCOX  4950314326.40             Willcox
# 15                     YUMA  2050496297.41                Yuma
#
#                                                  path  \
# 0   /Users/danielletadych/Documents/PhD_Materials/...
# 1   /Users/danielletadych/Documents/PhD_Materials/...
# 2   /Users/danielletadych/Documents/PhD_Materials/...
# 3   /Users/danielletadych/Documents/PhD_Materials/...
# 4   /Users/danielletadych/Documents/PhD_Materials/...
# 5   /Users/danielletadych/Documents/PhD_Materials/...
# 6   /Users/danielletadych/Documents/PhD_Materials/...
# 7   /Users/danielletadych/Documents/PhD_Materials/...
# 8   /Users/danielletadych/Documents/PhD_Materials/...
# 9   /Users/danielletadych/Documents/PhD_Materials/...
# 10  /Users/danielletadych/Documents/PhD_Materials/...
# 11  /Users/danielletadych/Documents/PhD_Materials/...
# 12  /Users/danielletadych/Documents/PhD_Materials/...
# 13  /Users/danielletadych/Documents/PhD_Materials/...
# 14  /Users/danielletadych/Documents/PhD_Materials/...
# 15  /Users/danielletadych/Documents/PhD_Materials/...
#
#                                              geometry
# 0   POLYGON Z ((-111.38373 32.44680 0.00000, -111....
# 1   POLYGON Z ((-111.34431 32.24769 0.00000, -111....
# 2   POLYGON Z ((-111.34573 32.24836 0.00000, -111....
# 3   POLYGON Z ((-111.76613 35.19826 0.00000, -111....
# 4   MULTIPOLYGON Z (((-109.04629 35.62503 0.00000,...
# 5   POLYGON Z ((-109.61347 31.33412 0.00000, -109....
# 6   MULTIPOLYGON Z (((-112.40962 33.58074 0.00000,...
# 7   POLYGON Z ((-112.58193 33.26550 0.00000, -112....
# 8   POLYGON Z ((-113.30171 33.83493 0.00000, -113....
# 9   POLYGON Z ((-113.38354 34.05454 0.00000, -113....
# 10  POLYGON Z ((-113.87749 33.95926 0.00000, -113....
# 11  POLYGON Z ((-111.04103 33.95188 0.00000, -111....
# 12  POLYGON Z ((-111.04407 32.32092 0.00000, -111....
# 13  POLYGON Z ((-111.81927 35.38284 0.00000, -111....
# 14  POLYGON Z ((-110.04731 32.73044 0.00000, -110....
# 15  POLYGON Z ((-114.46620 32.88249 0.00000, -114....

# %%
# Define some things about your file

StudyArea = "Poster_UnregAg"
Naming_col = "Name"
water_designation = cap_secondary

# %% [markdown]
# Merging the databases takes a little time - Approximately 0.1-3 minutes

# %%
# Merge the shapefile with the master database

shapefile = shapefile.to_crs(epsg=26912)
masterdb2 = masterdb.set_crs(epsg=26912)
masterdb_water = masterdb_water.set_crs(epsg=26912)
# For main static database
static_geo = gp.sjoin(masterdb2, shapefile, how="inner", op='intersects')

print(str(filename_mdb_nd) + " and " + str(filename_shapeile) + " join complete.")

# %% For the water wells water wells
static_geo2 = gp.sjoin(masterdb_water, shapefile, how="inner", op='intersects')
static_geo2.head()
print(str(filename_mdb_nd) + " and " + str(filename_shapeile) + " join complete.")
# Out:
# c:\Users\det19\.conda\envs\azgwspatialanalysis\lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# Master_ADWR_database_noduplicates.shp and AllCaseStudies.shp join complete.
# c:\Users\det19\.conda\envs\azgwspatialanalysis\lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# Master_ADWR_database_noduplicates.shp and AllCaseStudies.shp join complete.

# %%
static_geo
# Out:
#        Combo_ID          SITE_ID       LOCAL_ID REGISTRY_I WELL_TYPE  DD_LAT  \
# 1        060001  334708112295301  B-05-02 08CCB     060001     INDEX   33.79
# 52       084818              NaN            NaN     084818       NaN     NaN
# 75       084954              NaN            NaN     084954       NaN     NaN
# 122      085006              NaN            NaN     085006       NaN     NaN
# 123      085007              NaN            NaN     085007       NaN     NaN
# ...         ...              ...            ...        ...       ...     ...
# 249633   928408              NaN            NaN     928408       NaN     NaN
# 249838   928615              NaN            NaN     928615       NaN     NaN
# 250184   928969              NaN            NaN     928969       NaN     NaN
# 250831   929636              NaN            NaN     929636       NaN     NaN
# 250856   929661              NaN            NaN     929661       NaN     NaN
#
#         DD_LONG  WELL_ALT  WATER_USE_  WELL_DEPTH  ...  index_right  \
# 1       -112.50   1702.00  INDUSTRIAL     1000.00  ...            6
# 52          NaN       NaN         NaN      810.00  ...            6
# 75          NaN       NaN         NaN      280.00  ...            6
# 122         NaN       NaN         NaN        0.00  ...            6
# 123         NaN       NaN         NaN      600.00  ...            6
# ...         ...       ...         ...         ...  ...          ...
# 249633      NaN       NaN         NaN      220.00  ...            3
# 249838      NaN       NaN         NaN      240.00  ...            3
# 250184      NaN       NaN         NaN      280.00  ...            3
# 250831      NaN       NaN         NaN         NaN  ...            3
# 250856      NaN       NaN         NaN         NaN  ...            3
#
#              Name   FID  AMA_CODE SUBBASIN_N_right NAME_ABBR SUBBASIN_1  \
# 1         Phoenix 78.00       NaN              NaN       NaN        NaN
# 52        Phoenix 78.00       NaN              NaN       NaN        NaN
# 75        Phoenix 78.00       NaN              NaN       NaN        NaN
# 122       Phoenix 78.00       NaN              NaN       NaN        NaN
# 123       Phoenix 78.00       NaN              NaN       NaN        NaN
# ...           ...   ...       ...              ...       ...        ...
# 249633  Flagstaff 14.00       NaN              NaN       NaN        NaN
# 249838  Flagstaff 14.00       NaN              NaN       NaN        NaN
# 250184  Flagstaff 14.00       NaN              NaN       NaN        NaN
# 250831  Flagstaff 14.00       NaN              NaN       NaN        NaN
# 250856  Flagstaff 14.00       NaN              NaN       NaN        NaN
#
#        SHAPEAREA               layer  \
# 1            NaN     Phoenix (Urban)
# 52           NaN     Phoenix (Urban)
# 75           NaN     Phoenix (Urban)
# 122          NaN     Phoenix (Urban)
# 123          NaN     Phoenix (Urban)
# ...          ...                 ...
# 249633       NaN  Flagstaff_Buffered
# 249838       NaN  Flagstaff_Buffered
# 250184       NaN  Flagstaff_Buffered
# 250831       NaN  Flagstaff_Buffered
# 250856       NaN  Flagstaff_Buffered
#
#                                                      path
# 1       /Users/danielletadych/Documents/PhD_Materials/...
# 52      /Users/danielletadych/Documents/PhD_Materials/...
# 75      /Users/danielletadych/Documents/PhD_Materials/...
# 122     /Users/danielletadych/Documents/PhD_Materials/...
# 123     /Users/danielletadych/Documents/PhD_Materials/...
# ...                                                   ...
# 249633  /Users/danielletadych/Documents/PhD_Materials/...
# 249838  /Users/danielletadych/Documents/PhD_Materials/...
# 250184  /Users/danielletadych/Documents/PhD_Materials/...
# 250831  /Users/danielletadych/Documents/PhD_Materials/...
# 250856  /Users/danielletadych/Documents/PhD_Materials/...
#
# [96973 rows x 82 columns]

# %%
# Pull out the columns you need
# Use this or subbasins:
# reg_list = static_geo[['Combo_ID', Naming_col+'_right','WELL_DEPTH','WELL_TYPE_']]
# Use this or cities:
reg_list = static_geo[['Combo_ID', Naming_col,'WELL_DEPTH','WELL_TYPE_']]
reg_list

# %% Converting Combo_ID to int
reg_list['Combo_ID'] = reg_list['Combo_ID'].astype(np.int64, errors = 'raise')
# Out:
# C:\Users\det19\AppData\Local\Temp\ipykernel_17644\2831234236.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_list['Combo_ID'] = reg_list['Combo_ID'].astype(np.int64, errors = 'raise')

# %%
# Merging the Timeseries and the shapefile static database
combo = annual_db2.merge(reg_list, how="inner")
combo.info()

# %% set index to Combo_ID
combo.set_index('Combo_ID', inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Columns: 163 entries, Combo_ID to WELL_TYPE_
# dtypes: float64(160), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
# Grouping the appropriate column
combo_copy = combo.copy()
combo_copy = combo_copy.drop(['WELL_DEPTH','WELL_TYPE_'],axis=1)
# cat_wl = combo_copy.groupby([Naming_col+"_right"]).mean()
cat_wl = combo_copy.groupby([Naming_col]).mean()

# %%
# Clean up the dataframe for graphing
cat_wl2 = cat_wl.copy()
i = cat_wl2
# del i['WELL_DEPTH']
f = i.transpose()
f.reset_index(inplace=True)
f['index'] = pd.to_numeric(f['index'])
f['index'] = f['index'].astype(int)
f.set_index('index', inplace=True)
f.info()
cat_wl2 = f
cat_wl2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 1853 to 2023
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Control        59 non-null     float64
#  1   Douglas        77 non-null     float64
#  2   Flagstaff      56 non-null     float64
#  3   GSF/USF        83 non-null     float64
#  4   GilaBend       75 non-null     float64
#  5   Harquahala     70 non-null     float64
#  6   LittleCoR      80 non-null     float64
#  7   McMullen       72 non-null     float64
#  8   Phoenix        91 non-null     float64
#  9   RanegrasPlain  76 non-null     float64
#  10  SaltRiver      40 non-null     float64
#  11  Tucson         97 non-null     float64
#  12  USF            74 non-null     float64
#  13  Verde          70 non-null     float64
#  14  Wilcox         80 non-null     float64
#  15  Yuma           81 non-null     float64
# dtypes: float64(16)
# memory usage: 20.5 KB
# Name   Control  Douglas  Flagstaff  GSF/USF  GilaBend  Harquahala  LittleCoR  \
# index
# 1853       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1856       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1857       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1860       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1864       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# ...        ...      ...        ...      ...       ...         ...        ...
# 2019    323.55   182.54     391.59   188.12    298.62      325.88     216.82
# 2020    323.77   188.87     392.92   187.69    342.60      367.32     226.70
# 2021       NaN   190.67     394.16   179.77    345.70      372.75     227.53
# 2022    352.60   190.60     445.26   181.01    349.55      441.98     238.50
# 2023    352.00    93.31     405.50   189.50    346.82      423.25     603.03
#
# Name   McMullen  Phoenix  RanegrasPlain  SaltRiver  Tucson    USF  Verde  \
# index
# 1853        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1856        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1857        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1860        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1864        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# ...         ...      ...            ...        ...     ...    ...    ...
# 2019     411.85   231.46         246.75       9.60  228.41 268.12 209.76
# 2020     427.41   232.73         260.36       5.50  234.33 274.52 207.85
# 2021     430.48   234.51         252.15       8.80  212.92 279.55 230.66
# 2022     416.11   232.55         255.61      10.03  207.91 273.25 219.40
# 2023     314.18   294.14         325.39        NaN  194.71 260.10 291.44
#
# Name   Wilcox   Yuma
# index
# 1853      NaN    NaN
# 1856      NaN    NaN
# 1857      NaN    NaN
# 1860      NaN    NaN
# 1864      NaN    NaN
# ...       ...    ...
# 2019   238.17  64.10
# 2020   255.31  62.19
# 2021   281.53  68.67
# 2022   287.22  69.95
# 2023    55.62 158.15
#
# [159 rows x 16 columns]

# %%
cat_wl2.head(-1)
# Out:
# Name   Control  Douglas  Flagstaff  GSF/USF  GilaBend  Harquahala  LittleCoR  \
# index
# 1853       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1856       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1857       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1860       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# 1864       NaN      NaN        NaN      NaN       NaN         NaN        NaN
# ...        ...      ...        ...      ...       ...         ...        ...
# 2018    329.89   197.08     366.31   192.36    303.04      329.15     217.55
# 2019    323.55   182.54     391.59   188.12    298.62      325.88     216.82
# 2020    323.77   188.87     392.92   187.69    342.60      367.32     226.70
# 2021       NaN   190.67     394.16   179.77    345.70      372.75     227.53
# 2022    352.60   190.60     445.26   181.01    349.55      441.98     238.50
#
# Name   McMullen  Phoenix  RanegrasPlain  SaltRiver  Tucson    USF  Verde  \
# index
# 1853        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1856        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1857        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1860        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# 1864        NaN      NaN            NaN        NaN     NaN    NaN    NaN
# ...         ...      ...            ...        ...     ...    ...    ...
# 2018     414.71   246.26         253.88      13.80  230.18 255.90 211.79
# 2019     411.85   231.46         246.75       9.60  228.41 268.12 209.76
# 2020     427.41   232.73         260.36       5.50  234.33 274.52 207.85
# 2021     430.48   234.51         252.15       8.80  212.92 279.55 230.66
# 2022     416.11   232.55         255.61      10.03  207.91 273.25 219.40
#
# Name   Wilcox  Yuma
# index
# 1853      NaN   NaN
# 1856      NaN   NaN
# 1857      NaN   NaN
# 1860      NaN   NaN
# 1864      NaN   NaN
# ...       ...   ...
# 2018   259.42 65.47
# 2019   238.17 64.10
# 2020   255.31 62.19
# 2021   281.53 68.67
# 2022   287.22 69.95
#
# [158 rows x 16 columns]

# %%
# Export the dataframe
# cat_wl2.to_csv(outputpath_local+'Waterlevels_AllCaseStudies.csv')

# %% [markdown]
# ### Analysis and Graphing

# %%
# Read in the drought indices

cat_wl2 = pd.read_csv(outputpath_local+'Waterlevels_AllCaseStudies.csv') 

cat_wl2 = cat_wl2.set_index('index')
cat_wl2
# Out:
#           Control     Douglas   Flagstaff     GSF/USF    GilaBend  Harquahala  \
# index
# 1853          NaN         NaN         NaN         NaN         NaN         NaN
# 1856          NaN         NaN         NaN         NaN         NaN         NaN
# 1857          NaN         NaN         NaN         NaN         NaN         NaN
# 1860          NaN         NaN         NaN         NaN         NaN         NaN
# 1864          NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 2019   323.554667  182.541296  391.593571  188.123704  298.622222  325.881458
# 2020   323.767059  188.872632  392.915952  187.691923  342.599615  367.315962
# 2021          NaN  190.672500  394.157381  179.771429  345.698750  372.746742
# 2022   352.600000  190.600784  445.260833  181.007143  349.545333  441.980833
# 2023   352.000000   93.310000  405.500000  189.500000  346.820000  423.255000
#
#         LittleCoR    McMullen     Phoenix  RanegrasPlain  SaltRiver  \
# index
# 1853          NaN         NaN         NaN            NaN        NaN
# 1856          NaN         NaN         NaN            NaN        NaN
# 1857          NaN         NaN         NaN            NaN        NaN
# 1860          NaN         NaN         NaN            NaN        NaN
# 1864          NaN         NaN         NaN            NaN        NaN
# ...           ...         ...         ...            ...        ...
# 2019   216.819664  411.852175  231.461031     246.746964       9.60
# 2020   226.704319  427.409855  232.727564     260.361333       5.50
# 2021   227.529977  430.478333  234.510732     252.152708       8.80
# 2022   238.497153  416.110500  232.553686     255.611458      10.03
# 2023   603.027778  314.180000  294.141607     325.390000        NaN
#
#            Tucson         USF       Verde      Wilcox        Yuma
# index
# 1853          NaN         NaN         NaN         NaN         NaN
# 1856          NaN         NaN         NaN         NaN         NaN
# 1857          NaN         NaN         NaN         NaN         NaN
# 1860          NaN         NaN         NaN         NaN         NaN
# 1864          NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 2019   228.412461  268.117703  209.763000  238.169062   64.098129
# 2020   234.333574  274.519412  207.847273  255.313192   62.185329
# 2021   212.923390  279.550000  230.662852  281.533200   68.671667
# 2022   207.906857  273.250000  219.399278  287.224231   69.945833
# 2023   194.706000  260.100000  291.445000   55.615000  158.150000
#
# [159 rows x 16 columns]

# %%
# Read in the drought indices
# drought_indices = pd.read_csv(datapath+'Yearly_DroughtIndices.csv')
drought_indices = pd.read_csv(inputpath_local+'/Yearly_DroughtIndices_updated12032023.csv') #this version doesn't have PHDI so adjust accordingly
drought_indices = drought_indices.set_index('In_year')
# drought_indices

# %%
Min_year_of_Study = 2000

# Water Analysis period
wlanalysis_period = cat_wl2[(cat_wl2.index>=Min_year_of_Study)&(cat_wl2.index<=2022)]
drought_indices = drought_indices[(drought_indices.index>=Min_year_of_Study)&(drought_indices.index<=2022)]
# del wlanalysis_period['Res'] # Only run this if doing regulation shapefile
wlanalysis_period.head()
# Out:
#           Control     Douglas   Flagstaff     GSF/USF    GilaBend  Harquahala  \
# index
# 2000   365.480000  153.191304  228.645625  230.051500  206.101364  345.449259
# 2001   360.796875         NaN  344.363889  225.286000  213.934792  340.248276
# 2002   358.915833  150.164286  243.998929  220.370000  222.669238  355.179375
# 2003   358.387500  157.442899  226.615833  208.780066  232.343182  339.227019
# 2004   352.460000  158.204545  227.842187  203.332803  239.064773  347.799823
#
#         LittleCoR    McMullen     Phoenix  RanegrasPlain  SaltRiver  \
# index
# 2000   270.664904  394.269802  266.786772     218.195588      11.60
# 2001   271.804433  410.203571  243.328750     194.169038      11.94
# 2002   277.697977  391.878816  248.606370     220.147353      13.34
# 2003   287.204646  409.598370  258.592584     230.363833      13.59
# 2004   285.629459  424.967375  244.222290     241.197917      12.86
#
#            Tucson         USF       Verde      Wilcox       Yuma
# index
# 2000   261.136556  380.373750  241.866250  226.353846  57.055000
# 2001   233.791235  385.273438  222.917885  226.705000  76.486667
# 2002   264.700586  401.431429  190.277917  219.696429  48.992500
# 2003   253.964069  399.110000  199.978963  226.312037  50.256741
# 2004   258.134433  400.579630  210.475429  220.621739  51.223269

# %%
wlanalysis_period
# Out:
#           Control     Douglas   Flagstaff     GSF/USF    GilaBend  Harquahala  \
# index
# 2000   365.480000  153.191304  228.645625  230.051500  206.101364  345.449259
# 2001   360.796875         NaN  344.363889  225.286000  213.934792  340.248276
# 2002   358.915833  150.164286  243.998929  220.370000  222.669238  355.179375
# 2003   358.387500  157.442899  226.615833  208.780066  232.343182  339.227019
# 2004   352.460000  158.204545  227.842187  203.332803  239.064773  347.799823
# 2005   355.257292  153.115000  215.096875  200.559087  211.266667  338.762276
# 2006   351.195882  158.009524  217.403125  196.246058  235.451852  341.329758
# 2007   328.660000  162.288889  224.029167  190.425917  251.470833  338.565786
# 2008   353.902000  181.192308  373.428750  188.032375  260.753261  288.410333
# 2009   339.315000  164.333333  375.979583  190.685625  271.989773  351.291897
# 2010   348.100625  176.620000  369.469375  188.224130  255.304348  359.189655
# 2011   339.787500  167.377273  371.230625  189.805098  263.081905  353.457056
# 2012   338.656250  173.030000  370.050208  192.788889  278.305833  357.958391
# 2013   337.481875  173.959079  344.091111  192.282284  277.942500  346.125128
# 2014   337.228750   78.160000  342.192963  196.309000  261.867500  347.900104
# 2015   335.338750  173.495000  341.372963  193.868765  281.532540  354.415200
# 2016   333.490714  183.747255  345.832593  193.520123  305.662281  357.601771
# 2017   332.148235  193.794561  336.531667  190.950128  272.342105  318.239649
# 2018   329.893846  197.076250  366.305833  192.359038  303.041304  329.145667
# 2019   323.554667  182.541296  391.593571  188.123704  298.622222  325.881458
# 2020   323.767059  188.872632  392.915952  187.691923  342.599615  367.315962
# 2021          NaN  190.672500  394.157381  179.771429  345.698750  372.746742
# 2022   352.600000  190.600784  445.260833  181.007143  349.545333  441.980833
#
#         LittleCoR    McMullen     Phoenix  RanegrasPlain  SaltRiver  \
# index
# 2000   270.664904  394.269802  266.786772     218.195588      11.60
# 2001   271.804433  410.203571  243.328750     194.169038      11.94
# 2002   277.697977  391.878816  248.606370     220.147353      13.34
# 2003   287.204646  409.598370  258.592584     230.363833      13.59
# 2004   285.629459  424.967375  244.222290     241.197917      12.86
# 2005   297.267857  402.189632  261.028287     234.596333      10.59
# 2006   284.686202  412.821176  256.378112     232.929028      10.78
# 2007   222.760303  405.923214  251.283561     231.529647      11.48
# 2008   180.408170  423.805482  232.891485     214.386250        NaN
# 2009   223.360574  413.695978  239.956241     249.296667       8.34
# 2010   217.850380  404.140952  241.009028     239.243333       3.20
# 2011   218.559240  416.939848  259.876395     242.614222       4.45
# 2012   231.032873  409.573889  233.076490     261.974889       6.20
# 2013   225.154490  423.236087  237.145850     239.144333       5.30
# 2014   215.622306  409.762222  244.175942     246.893095       8.89
# 2015   212.395336  413.906491  253.543380     247.291190      15.30
# 2016   191.938420  402.745917  242.994593     241.916667      13.10
# 2017   197.566381  422.171061  232.073046     243.538000      11.80
# 2018   217.545362  414.712458  246.255114     253.879778      13.80
# 2019   216.819664  411.852175  231.461031     246.746964       9.60
# 2020   226.704319  427.409855  232.727564     260.361333       5.50
# 2021   227.529977  430.478333  234.510732     252.152708       8.80
# 2022   238.497153  416.110500  232.553686     255.611458      10.03
#
#            Tucson         USF       Verde      Wilcox       Yuma
# index
# 2000   261.136556  380.373750  241.866250  226.353846  57.055000
# 2001   233.791235  385.273438  222.917885  226.705000  76.486667
# 2002   264.700586  401.431429  190.277917  219.696429  48.992500
# 2003   253.964069  399.110000  199.978963  226.312037  50.256741
# 2004   258.134433  400.579630  210.475429  220.621739  51.223269
# 2005   249.627627  404.456897  198.238298  215.201250  52.116394
# 2006   242.427156  397.646410  200.257041  243.824138  53.483950
# 2007   259.988521  392.862500  193.686933  212.465129  60.731566
# 2008   251.785523  390.754054  177.767500  185.718705  52.404808
# 2009   255.053307  377.153000  195.088030  224.303478  57.354992
# 2010   241.588689  363.721176  195.896471  214.401487  57.125359
# 2011   239.458937  350.065676  186.078590  232.748571  57.849803
# 2012   238.068930  341.043594  209.735490  229.075992  59.615633
# 2013   234.911838  359.162414  204.349151  241.194136  59.547184
# 2014   237.409721  316.324125  180.155490  228.309310  59.782643
# 2015   208.016293  308.428000  195.811986  241.909874  60.126128
# 2016   231.318567  275.651522  198.507340  230.208083  62.373471
# 2017   244.300759  284.922105  206.028039  253.490437  64.131163
# 2018   230.184205  255.895517  211.790638  259.419524  65.474998
# 2019   228.412461  268.117703  209.763000  238.169062  64.098129
# 2020   234.333574  274.519412  207.847273  255.313192  62.185329
# 2021   212.923390  279.550000  230.662852  281.533200  68.671667
# 2022   207.906857  273.250000  219.399278  287.224231  69.945833

# %% [markdown]
# This is helpful if you're missing values and it won't calculate statistics

# %%
df_interpolated = wlanalysis_period.interpolate(method='linear', axis=0)
df_interpolated
# Out:
#           Control     Douglas   Flagstaff     GSF/USF    GilaBend  Harquahala  \
# index
# 2000   365.480000  153.191304  228.645625  230.051500  206.101364  345.449259
# 2001   360.796875  151.677795  344.363889  225.286000  213.934792  340.248276
# 2002   358.915833  150.164286  243.998929  220.370000  222.669238  355.179375
# 2003   358.387500  157.442899  226.615833  208.780066  232.343182  339.227019
# 2004   352.460000  158.204545  227.842187  203.332803  239.064773  347.799823
# 2005   355.257292  153.115000  215.096875  200.559087  211.266667  338.762276
# 2006   351.195882  158.009524  217.403125  196.246058  235.451852  341.329758
# 2007   328.660000  162.288889  224.029167  190.425917  251.470833  338.565786
# 2008   353.902000  181.192308  373.428750  188.032375  260.753261  288.410333
# 2009   339.315000  164.333333  375.979583  190.685625  271.989773  351.291897
# 2010   348.100625  176.620000  369.469375  188.224130  255.304348  359.189655
# 2011   339.787500  167.377273  371.230625  189.805098  263.081905  353.457056
# 2012   338.656250  173.030000  370.050208  192.788889  278.305833  357.958391
# 2013   337.481875  173.959079  344.091111  192.282284  277.942500  346.125128
# 2014   337.228750   78.160000  342.192963  196.309000  261.867500  347.900104
# 2015   335.338750  173.495000  341.372963  193.868765  281.532540  354.415200
# 2016   333.490714  183.747255  345.832593  193.520123  305.662281  357.601771
# 2017   332.148235  193.794561  336.531667  190.950128  272.342105  318.239649
# 2018   329.893846  197.076250  366.305833  192.359038  303.041304  329.145667
# 2019   323.554667  182.541296  391.593571  188.123704  298.622222  325.881458
# 2020   323.767059  188.872632  392.915952  187.691923  342.599615  367.315962
# 2021   338.183529  190.672500  394.157381  179.771429  345.698750  372.746742
# 2022   352.600000  190.600784  445.260833  181.007143  349.545333  441.980833
#
#         LittleCoR    McMullen     Phoenix  RanegrasPlain  SaltRiver  \
# index
# 2000   270.664904  394.269802  266.786772     218.195588      11.60
# 2001   271.804433  410.203571  243.328750     194.169038      11.94
# 2002   277.697977  391.878816  248.606370     220.147353      13.34
# 2003   287.204646  409.598370  258.592584     230.363833      13.59
# 2004   285.629459  424.967375  244.222290     241.197917      12.86
# 2005   297.267857  402.189632  261.028287     234.596333      10.59
# 2006   284.686202  412.821176  256.378112     232.929028      10.78
# 2007   222.760303  405.923214  251.283561     231.529647      11.48
# 2008   180.408170  423.805482  232.891485     214.386250       9.91
# 2009   223.360574  413.695978  239.956241     249.296667       8.34
# 2010   217.850380  404.140952  241.009028     239.243333       3.20
# 2011   218.559240  416.939848  259.876395     242.614222       4.45
# 2012   231.032873  409.573889  233.076490     261.974889       6.20
# 2013   225.154490  423.236087  237.145850     239.144333       5.30
# 2014   215.622306  409.762222  244.175942     246.893095       8.89
# 2015   212.395336  413.906491  253.543380     247.291190      15.30
# 2016   191.938420  402.745917  242.994593     241.916667      13.10
# 2017   197.566381  422.171061  232.073046     243.538000      11.80
# 2018   217.545362  414.712458  246.255114     253.879778      13.80
# 2019   216.819664  411.852175  231.461031     246.746964       9.60
# 2020   226.704319  427.409855  232.727564     260.361333       5.50
# 2021   227.529977  430.478333  234.510732     252.152708       8.80
# 2022   238.497153  416.110500  232.553686     255.611458      10.03
#
#            Tucson         USF       Verde      Wilcox       Yuma
# index
# 2000   261.136556  380.373750  241.866250  226.353846  57.055000
# 2001   233.791235  385.273438  222.917885  226.705000  76.486667
# 2002   264.700586  401.431429  190.277917  219.696429  48.992500
# 2003   253.964069  399.110000  199.978963  226.312037  50.256741
# 2004   258.134433  400.579630  210.475429  220.621739  51.223269
# 2005   249.627627  404.456897  198.238298  215.201250  52.116394
# 2006   242.427156  397.646410  200.257041  243.824138  53.483950
# 2007   259.988521  392.862500  193.686933  212.465129  60.731566
# 2008   251.785523  390.754054  177.767500  185.718705  52.404808
# 2009   255.053307  377.153000  195.088030  224.303478  57.354992
# 2010   241.588689  363.721176  195.896471  214.401487  57.125359
# 2011   239.458937  350.065676  186.078590  232.748571  57.849803
# 2012   238.068930  341.043594  209.735490  229.075992  59.615633
# 2013   234.911838  359.162414  204.349151  241.194136  59.547184
# 2014   237.409721  316.324125  180.155490  228.309310  59.782643
# 2015   208.016293  308.428000  195.811986  241.909874  60.126128
# 2016   231.318567  275.651522  198.507340  230.208083  62.373471
# 2017   244.300759  284.922105  206.028039  253.490437  64.131163
# 2018   230.184205  255.895517  211.790638  259.419524  65.474998
# 2019   228.412461  268.117703  209.763000  238.169062  64.098129
# 2020   234.333574  274.519412  207.847273  255.313192  62.185329
# 2021   212.923390  279.550000  230.662852  281.533200  68.671667
# 2022   207.906857  273.250000  219.399278  287.224231  69.945833

# %%
StudyArea = 'Yuma'

# %%
# This is to delete some columns as needed
columns_to_delete = ['Control','GSF/USF','USF'
                     ,'Harquahala'
                     ,'SaltRiver'
                     ,'Douglas'
                     ,'Verde','GilaBend'
                     ,'Tucson','Phoenix'
                     ,'McMullen'
                     ,'RanegrasPlain'
                     ,'Flagstaff'
                     ,'LittleCoR'
                    #  ,'Yuma'
                    ,'Wilcox'
                    ]
df = df_interpolated.drop(columns=columns_to_delete)
# colors_to_delete=[blind[0],blind[3],blind[4],blind[7],blind[8],blind[9],blind[13],blind[14]]
# refined_blind_colors = blind.copy()
# refined_blind_colors = [blind[11],blind[12]]
# for color in colors_to_delete:
#     refined_blind_colors.remove(color)
# refined_blind_colors.reverse()
# refined_blind_colors
# refined_blind_colors = ['#332288', '#166C98', '#44AA99', '#117733', '#C3B050', '#B83E23', '#882255', '#AA4499']
refined_blind_colors = [
                        # '#808080',
                        '#117733']

# Orange / Purple
# refined_blind_colors = ["#b35806","#f1a340",'#98745c','#808080','#d8daeb','#998ec3','#542788']
# refined_blind_colors = ['#b35806', '#a86638', '#98745c', '#808080', '#cf98ee', '#8453b9', '#3f1374']
# refined_blind_colors = ['#b35806', '#98745c', '#808080', '#cf98ee', '#8453b9', '#3f1374']
# Colors for Tucson and Phoenix
# refined_blind_colors = ['#8453b9', '#3f1374']

# Dark Red / Blue
# refined_blind_colors = ['#00429d', '#3a64ac', '#5a88ba', '#a6a6a6', '#d55f71', '#c12550', '#93003a']

# Blue Red
# refined_blind_colors = ['#00429d', '#495594', '#686a8b', '#808080', '#f89672', '#bf452b', '#6e0000']
# refined_blind_colors.reverse()

# Create a bar plot to visualize colors
fig, ax = plt.subplots(figsize=(8, 1))
ax.bar(range(len(refined_blind_colors)), height=1, color=refined_blind_colors)

# Remove y-axis
ax.set_yticks([])

# Show the plot
plt.show()

# %%
# Reorder the dataframe

test = pd.DataFrame()
# test['Verde'] = df['Verde']
# test['Gila Bend'] = df['GilaBend']
# test['Wilcox'] = dtw_max_anomalies['Wilcox']
# test['Ranegras Plain'] = dtw_max_anomalies['RanegrasPlain']
# test['Douglas'] = dtw_max_anomalies['Douglas']
# test['McMullen'] = dtw_max_anomalies['McMullen']
test['Yuma'] = df['Yuma']
# test['Phoenix'] = df['Phoenix']
# test['Tucson'] = df['Tucson']
# test['Little Colorado \nRiver Basin'] = df['LittleCoR']
test
# Out:
#             Yuma
# index
# 2000   57.055000
# 2001   76.486667
# 2002   48.992500
# 2003   50.256741
# 2004   51.223269
# 2005   52.116394
# 2006   53.483950
# 2007   60.731566
# 2008   52.404808
# 2009   57.354992
# 2010   57.125359
# 2011   57.849803
# 2012   59.615633
# 2013   59.547184
# 2014   59.782643
# 2015   60.126128
# 2016   62.373471
# 2017   64.131163
# 2018   65.474998
# 2019   64.098129
# 2020   62.185329
# 2021   68.671667
# 2022   69.945833

# %%
# secondary = pd.DataFrame()
# secondary['Little Colorado \nRiver Basin'] = df['LittleCoR']
# secondary['Salt River'] = df['SaltRiver']
# secondary['Yuma'] = df['Yuma']

# %%
# For Depth to Water for all Case Studies
# ds = wlanalysis_period
# ds = df
ds = test
# ds = secondary
min_yr = 2000
mx_yr = 2022
Name = "mean_"+StudyArea
betterlabels = ds.columns.tolist()

f = ds[(ds.index >= min_yr) & (ds.index <= mx_yr)]
columns = ds.columns
column_list = ds.columns.tolist()

stats = pd.DataFrame()
# for i in range(1, 12, 1):
for i in column_list:
        df = f[i]
        #print(df)
        y=np.array(df.values, dtype=float)
        x=np.array(pd.to_datetime(df).index.values, dtype=float)
        slope, intercept, r_value, p_value, std_err =sp.linregress(x,y)
        stats = stats._append({'slope': slope, 
                              'int':intercept, 
                              'rsq':r_value*r_value, 
                              'p_val':p_value, 
                              'std_err':std_err, 
                              'mean': np.mean(y),
                              'var': np.var(y),
                              'sum': np.sum(y)
                              },
                              ignore_index=True)


stats.index = betterlabels
stats = stats.sort_values(by='slope', ascending=False)
stats1 = stats.transpose()
print(stats)
stats.to_csv(outputpath_local+'Stats_'+StudyArea+'.csv')

# -- Data visualization --

fig, ax = plt.subplots(1, 1, figsize = (6,4))

min_y = 0
max_y = 100
fsize = 15

# Set's ticks to one per year:
# num_years = mx_yr - min_yr + 1
# ax.set_xticks(np.linspace(min_yr, mx_yr, num_years))
# ax.set_xticklabels(map(int, ax.get_xticks()))

# Set x ticks to every 5 years:
xticks = np.arange(min_yr, mx_yr + 1, 5)
ax.set_xticks(xticks)

# Ensure that the labels are integers
ax.set_xticklabels(map(int, xticks))

# Drought Year Shading
a = 1988
b = 1990
c = 1995
d = 1996
e = 2021
f = 2022
g = 2002
h = 2004
i = 2005
j = 2008
k = 2012
l = 2015
m = 2018
n = 2019
ax[0].axvspan(a, b, color=drought_color, alpha=0.5, lw=0
            , label="Severe Drought"
            )
plt.axvspan(c, d, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(e, f, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(g, h, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(i, j, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(k, l, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(m, n, color=drought_color, alpha=0.5, lw=0)

# Plotting the data
for i,j in zip(stats1.columns,refined_blind_colors):
        ax.plot(ds[i],color=j, label=str(i),lw=2)
# ax.plot(ds[column_list[0]], color=water_designation)
# ax.plot(ds[column_list[0]], color=blind[1],label=betterlabels[0]) 
# ax.plot(ds[column_list[1]], color=blind[2],label=betterlabels[1]) 
# ax.plot(ds[column_list[2]], color=blind[6],label=betterlabels[2])  
xf = np.linspace(min(x),max(x),100)
xf1 = xf.copy()

# Plotting Trendlines
for i,j in zip(stats1.columns,refined_blind_colors):
        #xf1 = pd.to_datetime(xf1)
        m1 = round(stats1.loc['slope',i], 2)
        yint1 = round(stats1.loc['int',i], 2)
        pval1 = round(stats1.loc['p_val',i], 4)
        yf1 = (m1*xf)+yint1
        # ax.plot(xf1, yf1,"-.",color=blind[j], lw=1)
        ax.plot(xf1, yf1,"-.",color=j, lw=1)

ax.set_xlim(min_yr,mx_yr)
ax.set_ylim(max_y,min_y)
# ax.grid(True)
# ax.grid(visible=True,which='major')
# ax.grid(which='minor',color='#EEEEEE', lw=0.8)
ax.set_xlabel('Year', fontsize=fsize)
ax.set_ylabel('Depth to Water (ft)',fontsize=fsize)
# ax.minorticks_on()
ax.tick_params(axis='y', labelsize=fsize)
ax.tick_params(axis='x', labelsize = fsize, rotation=45)
fig.set_dpi(600.0)
# ax.set_title('a)',loc='left',pad=15)
ax.legend(loc='lower right',fontsize = fsize)
# ax.legend(loc=[1.1,0.5])


plt.savefig(figurepath+Name, bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # For Depth to Water for all Case Studies
#       2 # ds = wlanalysis_period
#       3 # ds = df
# ----> 4 ds = test
#       5 # ds = secondary
#       6 min_yr = 2000
#
# NameError: name 'test' is not defined

# %%
# Anomaly's
# Need to redo this line for some reason
df = df_interpolated.drop(columns=columns_to_delete)
# ds = wlanalysis_period.copy()
# ds = df_interpolated.copy()
ds = df.copy()
# columns = ds.columns
column_list = df.columns.tolist()
# trend_df = wlanalysis_period.copy()
# trend_df = df_interpolated.copy()
trend_df = df.copy()
dtw_anomalys = pd.DataFrame()
for i in column_list:
        # Subtracting against the mean
        # dtw_anomalys[i] = wlanalysis_period[i] - wlanalysis_period[i].mean()
        
        # Subtracting against the slope
        dataframe = ds[i]
        y=np.array(dataframe.values, dtype=float)
        x=np.array(pd.to_datetime(dataframe).index.values, dtype=float)
        slope, intercept, r_value, p_value, std_err = sp.linregress(x,y)
        # print(y)
        # slope, intercept = sp.linregress(x,y) 
        # trend_df[i] = (wlanalysis_period.index*slope) + intercept
        # dtw_anomalys[i] = wlanalysis_period[i] - trend_df[i]
        # trend_df[i] = (df_interpolated.index*slope) + intercept
        # dtw_anomalys[i] = df_interpolated[i] - trend_df[i]
        trend_df[i] = (df.index*slope) + intercept
        dtw_anomalys[i] = df[i] - trend_df[i]

dtw_anomalys.head()
# Out:
#             Yuma
# index
# 2000    3.270952
# 2001   22.172974
# 2002   -5.850838
# 2003   -5.116241
# 2004   -4.679358

# %%
# For Depth to Water by regulation
ds = dtw_anomalys
min_yr = 2000
mx_yr = 2022

columns = ds.columns
column_list = ds.columns.tolist()

fig, ax = plt.subplots(1, 1, figsize = (6,4))

min_y = -12
max_y = 15
fsize = 12
num_years = mx_yr - min_yr + 1
ax.set_xticks(np.linspace(min_yr, mx_yr, num_years))
ax.set_xticklabels(map(int, ax.get_xticks()))

# Drought Year Shading
a = 1988
b = 1990
c = 1995
d = 1996
e = 2021
f = 2022
g = 2002
h = 2004
i = 2005
j = 2008
k = 2012
l = 2015
m = 2018
n = 2019
plt.axvspan(a, b, color=drought_color, alpha=0.5, lw=0, label="Severe Drought")
plt.axvspan(c, d, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(e, f, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(g, h, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(i, j, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(k, l, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(m, n, color=drought_color, alpha=0.5, lw=0)

for i,j in zip(ds.columns,refined_blind_colors):
        ax.plot(ds[i],color=j, label=str(i),lw=2)
# ax.plot(ds[column_list[0]], color=water_designation, lw=1.5)
# ax.plot(ds[column_list[0]], color=blind[1],label=betterlabels[0]) 
# ax.plot(ds[column_list[1]], color=blind[2],label=betterlabels[1]) 
# ax.plot(ds[column_list[2]], color=blind[6],label=betterlabels[2])  

ax.set_xlim(min_yr,mx_yr)
# ax.set_ylim(min_y,max_y)
# ax.grid(True)
ax.grid(visible=True,which='major')
ax.grid(which='minor',color='#EEEEEE', lw=0.8)
ax.set_xlabel('Year', fontsize=fsize)
ax.set_ylabel('DTW Anomaly (ft)',fontsize=fsize)
# ax.minorticks_on()
ax.tick_params(axis='x', rotation=45)
fig.set_dpi(600.0)
# ax.set_title('a)',loc='left',pad=15)
ax.legend(loc='upper center')

#Putting Grace on a secondary axis
# ax2 = ax.twinx()
# ax2.plot(grace_yearly['0'], label='State Average LWE', color='k',zorder=1)
# ax2.set_ylim([15, -15])
# ax2.set_ylabel(u'Δ LWE (cm)',fontsize=fsize)
# ax2.legend(loc='lower right')

plt.savefig(figurepath+'Timeseries of DTW Anomalies for '+StudyArea, bbox_inches = 'tight')

# %% [markdown]
# Calculating Max Drawdown (maximum anomaly in the drought period)

# %%
# %% Average Anomalie for drought periods
ds = dtw_anomalys.copy()
columns = ds.columns
column_list = ds.columns.tolist()

ds['Status'] = 'Normal-Wet'
# wlanalysis_period

for x,y in DROUGHT_YEARS.items():
        ds.loc[y, 'Status'] = 'Drought '+str(x)


dtw_max_anomalies = ds.groupby(['Status']).max()
dtw_max_anomalies
# ds
# Out:
#                  Yuma
# Status
# Drought 3   -5.116241
# Drought 4    3.240005
# Drought 5   -0.524152
# Drought 6    2.157345
# Drought 7    3.765079
# Normal-Wet  22.172974

# %%
# Reorder the dataframe

test = pd.DataFrame()
# test['Gila Bend'] = dtw_max_anomalies['GilaBend']
# test['Verde'] = dtw_max_anomalies['Verde']
# test['Wilcox'] = dtw_max_anomalies['Wilcox']
# test['Ranegras Plain'] = dtw_max_anomalies['RanegrasPlain']
# test['Douglas'] = dtw_max_anomalies['Douglas']
# test['McMullen'] = dtw_max_anomalies['McMullen']
test['Yuma'] = dtw_max_anomalies['Yuma']
# test['Phoenix'] = dtw_max_anomalies['Phoenix']
# test['Tucson'] = dtw_max_anomalies['Tucson']
# test['Little Colorado \nRiver Basin'] = dtw_max_anomalies['LittleCoR']
test
# Out:
#                  Yuma
# Status
# Drought 3   -5.116241
# Drought 4    3.240005
# Drought 5   -0.524152
# Drought 6    2.157345
# Drought 7    3.765079
# Normal-Wet  22.172974

# %%
#%% Grouped Bar chart for drawdown (ft)
# name = 'Average DTW Anomalies by Drought Period and Groundwater Regulation'
name = 'Max Drawdown by Drought Period for '+StudyArea

# ds = dtw_max_anomalies
ds = test

yearlabels = [
                # "1989-1990"
        #       ,'1996',
              '2002-2003','2006-2007','2012-2014','2018','2021'
              ,'Normal/Wet Years'
        ]
# betterlabels = ['CAP','Regulated \n Groundwater','Surface \n Water','Unregulated \n Groundwater','Mixed \n GW/SW'] 
# betterlabels = [StudyArea]
betterlabels = ds.columns.tolist()

ds.index = yearlabels
ds = ds.transpose()

ds.index = betterlabels
del ds['Normal/Wet Years']
ds = ds.transpose()


# group_colors = ['lightsalmon','tomato','orangered','r','brown','indianred','steelblue']

# group_colors = [blind[0],blind[2],blind[6]
#                 ,blind[12],blind[11],blind[10]
#                 # ,blind[0] #black
                # ]
# group_colors = [water_designation]
group_colors =refined_blind_colors

# horlabel = 'DTW Anomaly (ft)'
horlabel = 'Max Drawdown (ft)'
fsize = 14

plt.rcParams["figure.dpi"] = 600
ds.plot(figsize = (6,4),
        kind='bar',
        stacked=False,
        # title=name,
        # color = group_colors,
        color = refined_blind_colors,
        zorder = 2,
        width = 0.85,
        fontsize = fsize
        )
# plt.title(name, fontsize = (fsize+2))
plt.ylim([30,-10])
plt.ylabel(horlabel, fontsize = fsize)
plt.xticks(rotation=30, fontsize = fsize)
plt.grid(axis='y', linewidth=0.5, zorder=0)
plt.legend(loc=[1.01,0.3],fontsize = fsize)
# plt.set_dpi(600)

# plt.savefig(figurepath+name+'_anomalies_groupedchart', bbox_inches = 'tight')

# %%
# New wells

static_geo2['INSTALLED'] = pd.to_datetime(static_geo2['INSTALLED'])
# static_geo2['INSTALLED'].describe()

static_geo2['In_year'] = static_geo2['INSTALLED'].dt.year
# new_wells = pd.pivot_table(static_geo2, index=["In_year"], columns=[Naming_col+"_right"], values=["INSTALLED"], dropna=False, aggfunc=len)
new_wells = pd.pivot_table(static_geo2, index=["In_year"], columns=[Naming_col], values=["INSTALLED"], dropna=False, aggfunc=len)
# new_wells = new_wells.reset_index()

new_wells.to_csv(outputpath_local+'Final_NewWells_'+StudyArea+'.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 # New wells
# ----> 3 static_geo2['INSTALLED'] = pd.to_datetime(static_geo2['INSTALLED'])
#       4 # static_geo2['INSTALLED'].describe()
#       6 static_geo2['In_year'] = static_geo2['INSTALLED'].dt.year
#
# NameError: name 'static_geo2' is not defined

# %%
# To get it formatted correctly
all_columns = wlanalysis_period.columns.tolist()
new_wells2 = pd.read_csv(outputpath_local+'Final_NewWells_'+StudyArea+'.csv',
                        header=2,
                        # names = ['R','Res','U']
                        names = all_columns
                        # names = [StudyArea]
                        , index_col=0
                        )
new_wells2
# Out:
#          Control  Douglas  Flagstaff  GSF/USF  GilaBend  Harquahala  \
# 1900.00      NaN     1.00       1.00      NaN       NaN         NaN
# 1910.00      NaN      NaN        NaN      NaN       NaN         NaN
# 1915.00      NaN      NaN        NaN      NaN       NaN         NaN
# 1916.00      NaN      NaN        NaN      NaN       NaN         NaN
# 1917.00      NaN      NaN        NaN      NaN       NaN         NaN
# ...          ...      ...        ...      ...       ...         ...
# 2019.00      NaN    16.00       6.00     3.00     18.00        1.00
# 2020.00      NaN    19.00      11.00     4.00      2.00        4.00
# 2021.00     3.00    27.00      11.00     1.00      2.00        1.00
# 2022.00     1.00    24.00      13.00     3.00      1.00        2.00
# 2023.00      NaN     9.00        NaN     1.00       NaN         NaN
#
#          LittleCoR  McMullen  Phoenix  RanegrasPlain  SaltRiver  Tucson  USF  \
# 1900.00        NaN       NaN     1.00            NaN        NaN     NaN  NaN
# 1910.00       1.00       NaN      NaN            NaN        NaN     NaN  NaN
# 1915.00        NaN       NaN      NaN            NaN        NaN    1.00  NaN
# 1916.00       1.00       NaN      NaN            NaN        NaN     NaN  NaN
# 1917.00       1.00       NaN      NaN            NaN        NaN     NaN  NaN
# ...            ...       ...      ...            ...        ...     ...  ...
# 2019.00      41.00      6.00    63.00           7.00      15.00   10.00  NaN
# 2020.00      88.00     10.00    60.00           5.00      10.00   27.00  NaN
# 2021.00      73.00      9.00    47.00           5.00      29.00   17.00 2.00
# 2022.00      64.00      7.00    53.00           6.00       5.00   21.00  NaN
# 2023.00       6.00      1.00     8.00            NaN        NaN     NaN  NaN
#
#          Verde  Wilcox  Yuma
# 1900.00    NaN    1.00   NaN
# 1910.00    NaN     NaN   NaN
# 1915.00    NaN     NaN   NaN
# 1916.00    NaN     NaN   NaN
# 1917.00    NaN     NaN   NaN
# ...        ...     ...   ...
# 2019.00  17.00  103.00 17.00
# 2020.00  38.00   72.00 40.00
# 2021.00  28.00   66.00 75.00
# 2022.00  21.00   71.00 32.00
# 2023.00    NaN    7.00  6.00
#
# [106 rows x 16 columns]

# %%
new_wells2 = new_wells2.drop(columns=columns_to_delete)
new_wells2.to_csv(outputpath_local+'Final_NewWells_'+StudyArea+'.csv')
new_wells2
# Out:
#          LittleCoR  Yuma
# 1900.00        NaN   NaN
# 1910.00       1.00   NaN
# 1915.00        NaN   NaN
# 1916.00       1.00   NaN
# 1917.00       1.00   NaN
# ...            ...   ...
# 2019.00      41.00 17.00
# 2020.00      88.00 40.00
# 2021.00      73.00 75.00
# 2022.00      64.00 32.00
# 2023.00       6.00  6.00
#
# [106 rows x 2 columns]

# %%
# For Depth to Water by regulation
ds = new_wells2
min_yr = 2000
mx_yr = 2022
# betterlabels = ['Regulated','Unregulated']

columns = ds.columns
column_list = ds.columns.tolist()

fig, ax = plt.subplots(1, 1, figsize = (6,4))

min_y = -12
max_y = 15
fsize = 12
num_years = mx_yr - min_yr + 1
ax.set_xticks(np.linspace(min_yr, mx_yr, num_years))
ax.set_xticklabels(map(int, ax.get_xticks()))

# Drought Year Shading
a = 1988
b = 1990
c = 1995
d = 1996
e = 2021
f = 2022
g = 2002
h = 2004
i = 2005
j = 2008
k = 2012
l = 2015
m = 2018
n = 2019
plt.axvspan(a, b, color=drought_color, alpha=0.5, lw=0, label="Severe Drought")
plt.axvspan(c, d, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(e, f, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(g, h, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(i, j, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(k, l, color=drought_color, alpha=0.5, lw=0)
plt.axvspan(m, n, color=drought_color, alpha=0.5, lw=0)

for i,j in zip(ds.columns,refined_blind_colors):
        ax.plot(ds[i],color=j, label=str(i),lw=2)
# ax.plot(ds[column_list[0]], color=water_designation, lw=1.5) 
# ax.plot(ds[column_list[0]], color=blind[1],label=betterlabels[0]) 
# ax.plot(ds[column_list[1]], color=blind[2],label=betterlabels[1]) 
# ax.plot(ds[column_list[2]], color=blind[6],label=betterlabels[2])  

ax.set_xlim(min_yr,mx_yr)
# ax.set_ylim(min_y,max_y)
# ax.grid(True)
ax.grid(visible=True,which='major')
ax.grid(which='minor',color='#EEEEEE', lw=0.8)
ax.set_xlabel('Year', fontsize=fsize)
ax.tick_params(axis='x', rotation=45)
ax.set_ylabel('New Wells (#)',fontsize=fsize)
# ax.minorticks_on()
fig.set_dpi(600.0)
# ax.set_title('a)',loc='left',pad=15)
ax.legend(loc='upper right')

#Putting Grace on a secondary axis
# ax2 = ax.twinx()
# ax2.plot(grace_yearly['0'], label='State Average LWE', color='k',zorder=1)
# ax2.set_ylim([15, -15])
# ax2.set_ylabel(u'Δ LWE (cm)',fontsize=fsize)
# ax2.legend(loc='lower right')

plt.savefig(figurepath+'Timeseries of New Wells for '+StudyArea, bbox_inches = 'tight')
